# %%
import numpy as np

# %%
def generate_data(
        n, m,
        dtype = np.complex128,
        p = 1.5):
    """
    generate something that has the proper shape
    """
    assert(m % 2 == 0)
    a = np.zeros((n, m/2+1), dtype = dtype)
    a[:] = np.random.randn(*a.shape) + 1j*np.random.randn(*a.shape)
    j, i = np.mgrid[0:n, 0:m/2+1]
    a /= (j**2 + i**2)**(p/2)
    a[0, 0] = 0.0
    return a

n0 = 48
n1 = 32
kbla = generate_data(n0, n1, p = 1.25)
bla = np.fft.irfft2(kbla).astype(np.float32)
print (bla.shape, bla.dtype)
bla.tofile("data0")
# Out:
# (48, 32) float32

# %%
bla0 = np.fromfile("data0", dtype = np.float32).reshape(n0, n1)
bla1 = np.fromfile("data1", dtype = np.float32).reshape(n1, n0)
print (np.average(np.abs(bla0.T - bla1)))
# Out:
# 0.0

# %%
def generate_data_3D(
        n,
        dtype = np.complex128,
        p = 1.5):
    """
    generate something that has the proper shape
    """
    assert(n % 2 == 0)
    a = np.zeros((n, n, n/2+1), dtype = dtype)
    a[:] = np.random.randn(*a.shape) + 1j*np.random.randn(*a.shape)
    k, j, i = np.mgrid[-n/2+1:n/2+1, -n/2+1:n/2+1, 0:n/2+1]
    k = (k**2 + j**2 + i**2)**.5
    k = np.roll(k, n//2+1, axis = 0)
    k = np.roll(k, n//2+1, axis = 1)
    a /= k**p
    a[0, :, :] = 0
    a[:, 0, :] = 0
    a[:, :, 0] = 0
    ii = np.where(k == 0)
    a[ii] = 0
    ii = np.where(k > n/3)
    a[ii] = 0
    return a

bla = generate_data_3D(32, p = 2)
print (bla.shape)
print (bla[:, 1, 1])
bla.tofile("data0")
# Out:
# (32, 32, 17)
# [  0.00000000e+00+0.j           4.15246029e-01-0.17288386j
#    6.90050714e-02-0.21453222j   9.36743425e-03-0.00976973j
#   -9.64104259e-03-0.01703578j   3.42096280e-02-0.02503913j
#   -1.56859174e-02-0.0066421j   -1.05978251e-02+0.00212969j
#   -8.07833000e-03+0.01385598j  -5.56919602e-03-0.02089763j
#   -4.30334888e-03+0.00750903j   0.00000000e+00+0.j           0.00000000e+00+0.j
#    0.00000000e+00+0.j           0.00000000e+00+0.j           0.00000000e+00+0.j
#    0.00000000e+00+0.j           0.00000000e+00+0.j           0.00000000e+00+0.j
#    0.00000000e+00+0.j           0.00000000e+00+0.j           0.00000000e+00+0.j
#    2.28526023e-03-0.01090379j  -3.50309921e-05-0.00132174j
#   -4.12721961e-04+0.00974069j  -5.45867064e-03+0.00542178j
#   -2.14131150e-02-0.01892067j   3.37575145e-02+0.06362042j
#   -5.62968813e-03-0.09572785j  -9.59111418e-02-0.01423154j
#    1.01717145e-01+0.17557772j  -2.35054793e-01-0.00259366j]

# %%
bla1 = np.fromfile("data2", dtype = np.float32).reshape(64, 64, 66)
print (bla1[0, 0, 0])
# Out:
# nan

# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
ax = plt.figure().add_subplot(111)
ax.imshow(bla1[:,0], interpolation = 'none')
# Out:
# <img src="data:image/png;base64,...">
