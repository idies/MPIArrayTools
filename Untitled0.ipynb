# %%
import numpy as np
import subprocess
# %matplotlib nbagg
import matplotlib.pyplot as plt

# %%
def generate_data_3D(
        n,
        dtype = np.complex128,
        p = 1.5):
    """
    generate something that has the proper shape
    """
    assert(n % 2 == 0)
    a = np.zeros((n, n, n/2+1), dtype = dtype)
    a[:] = np.random.randn(*a.shape) + 1j*np.random.randn(*a.shape)
    k, j, i = np.mgrid[-n/2+1:n/2+1, -n/2+1:n/2+1, 0:n/2+1]
    k = (k**2 + j**2 + i**2)**.5
    k = np.roll(k, n//2+1, axis = 0)
    k = np.roll(k, n//2+1, axis = 1)
    a /= k**p
    a[0, :, :] = 0
    a[:, 0, :] = 0
    a[:, :, 0] = 0
    ii = np.where(k == 0)
    a[ii] = 0
    ii = np.where(k > n/3)
    a[ii] = 0
    return a

bla = generate_data_3D(32, p = 2)
bla[:] = 0
bla[1, 1, 0] = 1
bla[1, 0, 1] = 1
bla[0, 1, 1] = 1
print (bla.shape)
bla.tofile("data0c")
# Out:
# (32, 32, 17)

# %%
plt.close('all')
subprocess.call(['rm', 'data*r'])
if subprocess.call(['make', 'resize']) == 0:
    subprocess.call(['mpirun.mpich',
                     '-np',
                     '2',
                     './resize',
                     '{0}'.format(bla.shape[0]),
                     '{0}'.format(bla.shape[1]),
                     '{0}'.format(bla.shape[2])])
    bla1 = np.fromfile("data0r", dtype = np.float32).reshape(32, 32, -1)
    ax = plt.figure(figsize=(6,3)).add_subplot(121)
    ax.imshow(bla1[:,0], interpolation = 'none')
    bla1 = np.fromfile("data1r", dtype = np.float32).reshape(64, 64, -1)
    ax = plt.gcf().add_subplot(122)
    ax.imshow(bla1[:,0], interpolation = 'none')
else:
    print 'compilation error'
# Out:
# <img src="data:image/png;base64,...">
