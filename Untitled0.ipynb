# %%
import numpy as np

# %%
def generate_data(
        n, m,
        dtype = np.complex128,
        p = 1.5):
    """
    generate something that has the proper shape
    """
    assert(m % 2 == 0)
    a = np.zeros((n, m/2+1), dtype = dtype)
    a[:] = np.random.randn(*a.shape) + 1j*np.random.randn(*a.shape)
    j, i = np.mgrid[0:n, 0:m/2+1]
    a /= (j**2 + i**2)**(p/2)
    a[0, 0] = 0.0
    return a

kbla = generate_data(256, 192, p = 1.25)
bla = np.fft.irfft2(kbla).astype(np.float32)
print (bla.shape, bla.dtype)
bla.tofile("data0")
# Out:
# (256, 192) float32

# %%
bla0 = np.fromfile("data0", dtype = np.float32).reshape(256, 192)
bla1 = np.fromfile("data1", dtype = np.float32).reshape(192, 256)
print (np.average(np.abs(bla0.T - bla1)))
# Out:
# 0.0

# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
ax = plt.figure(figsize=(5, 3)).add_subplot(121)
bla = np.fromfile("data0", dtype = np.float32).reshape(256, 192)
ax.imshow(bla)
ax.set_axis_off()
ax = plt.gcf().add_subplot(122)
bla = np.fromfile("data1", dtype = np.float32)
ax.imshow(bla.reshape(192, 256))
ax.set_axis_off()
# Out:
# <img src="data:image/png;base64,...">
