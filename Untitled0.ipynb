# %%
import numpy as np


def generate_data(
        n,
        bytes_per_float = 4,
        p = 1.5):
    """
    generate something that has the proper shape
    """
    assert(n % 2 == 0)
    a = np.zeros((n, n/2+1), dtype = 'c{0}'.format(bytes_per_float*2))
    a[:] = np.random.randn(*a.shape) + 1j*np.random.randn(*a.shape)
    j, i = np.mgrid[0:n, 0:n/2+1]
    a /= (j**2 + i**2)**(p/2)
    a[0, 0] = 0.0
    return a

kbla = generate_data(256, p = 1.25)
bla = np.fft.irfft2(kbla).astype(np.float32)
print (bla.shape, bla.dtype)
bla.tofile("data0")
# Out:
# (256, 256) float32
# -c:15: RuntimeWarning: divide by zero encountered in true_divide

# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
ax = plt.figure(figsize=(6, 3)).add_subplot(121)
bla = np.fromfile("data0", dtype = np.float32).reshape(256, 256)
ax.imshow(bla)
ax.set_axis_off()
ax = plt.gcf().add_subplot(122)
bla = np.fromfile("data1", dtype = np.float32)
print (bla.shape[0] / 256)
ax.imshow(bla.reshape(-1, 256))
ax.set_axis_off()
# Out:
# <img src="data:image/png;base64,...">
# 256.0
