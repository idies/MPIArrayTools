# %%
import numpy as np
import subprocess
# %matplotlib nbagg
import matplotlib.pyplot as plt
import pyfftw

# %%
def generate_data_3D(
        n,
        dtype = np.complex128,
        p = 1.5):
    """
    generate something that has the proper shape
    """
    assert(n % 2 == 0)
    a = np.zeros((n, n, n/2+1), dtype = dtype)
    a[:] = np.random.randn(*a.shape) + 1j*np.random.randn(*a.shape)
    k, j, i = np.mgrid[-n/2+1:n/2+1, -n/2+1:n/2+1, 0:n/2+1]
    k = (k**2 + j**2 + i**2)**.5
    k = np.roll(k, n//2+1, axis = 0)
    k = np.roll(k, n//2+1, axis = 1)
    a /= k**p
    a[0, :, :] = 0
    a[:, 0, :] = 0
    a[:, :, 0] = 0
    ii = np.where(k == 0)
    a[ii] = 0
    ii = np.where(k > n/3)
    a[ii] = 0
    return a

n = 32
N = 128

Kdata0 = generate_data_3D(n, p = 2).astype(np.complex64)
Kdata1 = generate_data_3D(n, p = 2).astype(np.complex64)
Kdata0.T.copy().tofile("Kdata0")
Kdata1.T.copy().tofile("Kdata1")

# %%
def padd_with_zeros(
        a,
        n,
        odtype = None):
    if (type(odtype) == type(None)):
        odtype = a.dtype
    assert(a.shape[0] <= n)
    b = np.zeros((n, n, n/2 + 1), dtype = odtype)
    m = a.shape[0]
    b[     :m/2,      :m/2, :m/2+1] = a[     :m/2,      :m/2, :m/2+1]
    b[     :m/2, n-m/2:   , :m/2+1] = a[     :m/2, m-m/2:   , :m/2+1]
    b[n-m/2:   ,      :m/2, :m/2+1] = a[m-m/2:   ,      :m/2, :m/2+1]
    b[n-m/2:   , n-m/2:   , :m/2+1] = a[m-m/2:   , m-m/2:   , :m/2+1]
    return b

def transform_py(bla):
    b = padd_with_zeros(bla, N)
    c = np.zeros((N, N, N), np.float32)
    t = pyfftw.FFTW(
        b, c,
        axes = (0, 1, 2),
        direction = 'FFTW_BACKWARD',
        flags = ('FFTW_ESTIMATE',),
        threads = 2)
    t.execute()
    return c

import chichi_misc as cm

def array_to_8cubes(
    a,
    odtype = None):
    assert(len(a.shape) >= 3)
    assert((a.shape[0] % 8 == 0) and
           (a.shape[1] % 8 == 0) and
           (a.shape[2] % 8 == 0))
    if type(odtype) == type(None):
        odtype = a.dtype
    b = a.reshape(
        *((a.shape[0] // 8, a.shape[1] // 8, a.shape[2] // 8) +
          (8, 8, 8) +
          a.shape[3:]))
    c = np.zeros(
        ((((a.shape[0] // 8)*(a.shape[1] // 8)*(a.shape[2] // 8)),) +
         (8, 8, 8) +
         a.shape[3:]),
        dtype = odtype)
    bk, bj, bi = np.mgrid[0:b.shape[0], 0:b.shape[1], 0:b.shape[2]]
    bindices = np.array([bk, bj, bi])
    cindices = cm.grid3D_to_zindex(bindices)
    c[cindices] = b[bk, bj, bi]
    return c

d0 = transform_py(Kdata0)
d1 = transform_py(Kdata1)

Rdata_py = np.array([d0, d1]).transpose((1, 2, 3, 0))
print(Rdata_py.shape)

Rdata_py = array_to_8cubes(Rdata_py).copy()
#Rdata1 = array_to_8cubes(transform_py(Kdata1))
# Out:
# (128, 128, 128, 2)

# %%
subprocess.call(['rm', 'Rdata'])
if subprocess.call(['make', 'full']) == 0:
    subprocess.call(['mpirun.mpich',
                     '-np',
                     '8',
                     './full',
                     '{0}'.format(n/2+1),
                     '{0}'.format(n),
                     '{0}'.format(n),
                     '{0}'.format(N),
                     '{0}'.format(N),
                     '{0}'.format(N)])
    Rdata = np.fromfile(
        "Rdata",
        dtype = np.float32).reshape(-1, 8, 8, 8, 2)
else:
    print ('compilation error')

# %%
plt.close('all')
yslice = np.random.randint(N)
ax = plt.figure(figsize=(6,3)).add_axes([.0, .0, .5, 1.])
ax.set_axis_off()
ax.imshow(Rdata_py.reshape(N, N, N, 2)[yslice, :, :, 0],
          interpolation = 'none',
          extent = [.0, 1., 1., 0.])
ax = plt.gcf().add_axes([.5, .0, .5, 1.])
ax.set_axis_off()
ax.imshow(Rdata.reshape(N, N, N, 2)[yslice, :, :, 0],
          interpolation = 'none',
          extent = [.0, 1., 1., 0.])
print(np.max(np.abs(Rdata0 - Rdata[..., 0])))
print(np.max(np.abs(Rdata1 - Rdata[..., 1])))
# Out:
# <img src="data:image/png;base64,...">
# 17.7776
# 17.688

# %%
ax = plt.figure().add_subplot(111)
ax.plot(Rdata[:128, 0, 4, 0, s0], marker = '.')
ax.plot(Rdata[:128, 0, 4, 0, 1], marker = '.')
# Out:
# <img src="data:image/png;base64,...">
